# %% [markdown]
# # Eksploratorna analiza i priprema skupa podataka

# %%
import pandas as pd
import numpy as np
import seaborn as sns 
import matplotlib.pyplot as plt
import scipy as sc

# %%
# Popis kriptovaluti
coins = ['Aave', 'BinanceCoin', 'Bitcoin', 'Cardano', 'ChainLink','Cosmos', 'CryptocomCoin', 'Dogecoin', 'EOS', 'Ethereum', 'Iota', 'Litecoin', 'Monero', 'NEM', 'Polkadot', 'Solana', 'Stellar', 'Tether', 'Tron', 'USDCoin', 'Uniswap', 'WrappedBitcoin', 'XRP']
dataframes = {}

# Učitavanje podataka
for coin in coins:
    file_path = f"../datasets/coin_{coin}.csv"
    try:
        dataframes[coin] = pd.read_csv(file_path)
    except FileNotFoundError:
        print(f"File for {coin} not found.")
        dataframes[coin] = None

# %% [markdown]
# Pregled količine podataka po kriptovaluti.

# %%
for coin,frame in dataframes.items():
    print(f"Number of values for {coin}: {len(frame)}")
# Out:
# Number of values for Aave: 275
# Number of values for BinanceCoin: 1442
# Number of values for Bitcoin: 2991
# Number of values for Cardano: 1374
# Number of values for ChainLink: 1385
# Number of values for Cosmos: 845
# Number of values for CryptocomCoin: 935
# Number of values for Dogecoin: 2760
# Number of values for EOS: 1466
# Number of values for Ethereum: 2160
# Number of values for Iota: 1484
# Number of values for Litecoin: 2991
# Number of values for Monero: 2602
# Number of values for NEM: 2288
# Number of values for Polkadot: 320
# Number of values for Solana: 452
# Number of values for Stellar: 2527
# Number of values for Tether: 2318
# Number of values for Tron: 1392
# Number of values for USDCoin: 1002
# Number of values for Uniswap: 292
# Number of values for WrappedBitcoin: 888
# Number of values for XRP: 2893

# %%
dataframes[coins[0]].head()
# Out:
#    SNo  Name Symbol                 Date       High        Low       Open  \
# 0    1  Aave   AAVE  2020-10-05 23:59:59  55.112358  49.787900  52.675035
# 1    2  Aave   AAVE  2020-10-06 23:59:59  53.402270  40.734578  53.291969
# 2    3  Aave   AAVE  2020-10-07 23:59:59  42.408314  35.970690  42.399947
# 3    4  Aave   AAVE  2020-10-08 23:59:59  44.902511  36.696057  39.885262
# 4    5  Aave   AAVE  2020-10-09 23:59:59  47.569533  43.291776  43.764463
#
#        Close        Volume     Marketcap
# 0  53.219243  0.000000e+00  8.912813e+07
# 1  42.401599  5.830915e+05  7.101144e+07
# 2  40.083976  6.828342e+05  6.713004e+07
# 3  43.764463  1.658817e+06  2.202651e+08
# 4  46.817744  8.155377e+05  2.356322e+08

# %% [markdown]
# ## Pregled metrika

# %% [markdown]
# Ovo je korisno za provjeru točnosti puno kompleksnijih izračuna u samom programu simulacije.

# %% [markdown]
# ### Aave

# %%
df = dataframes[coins[0]]
df['log_returns'] = np.log(df['Close'] / df['Open'])

plt.figure(figsize=(12, 7))
plt.plot(df.index, df['log_returns'], label='Vrijednost kroz vrijeme', color='deepskyblue', linewidth=2)
plt.title(coins[0] + ' povrati')
plt.xlabel('Datum')
plt.ylabel('Vrijednost')
plt.legend()
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(12, 7))
plt.plot(df.index, df['Close'], label='Vrijednost kroz vrijeme', color='deepskyblue', linewidth=2)
plt.title(coins[0] + ' cijene')
plt.xlabel('Datum')
plt.ylabel('Vrijednost')
plt.legend()
plt.grid(True)
plt.show()

# %%
mean_value = df['log_returns'].mean()
std_dev = df['log_returns'].std()

print(f"Prosječna vrijednost: {mean_value:.5f}")
print(f"Standardna devijacija: {std_dev:.5f}")
# Out:
# Prosječna vrijednost: 0.00679
# Standardna devijacija: 0.08588

# %% [markdown]
# ### BinanceCoin

# %%
df = dataframes[coins[1]]
df['log_returns'] = np.log(df['Close'] / df['Open'])

plt.figure(figsize=(12, 7))
plt.plot(df.index, df['log_returns'], label='Vrijednost kroz vrijeme', color='deepskyblue', linewidth=2)
plt.title(coins[1] + ' povrati')
plt.xlabel('Datum')
plt.ylabel('Vrijednost')
plt.legend()
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(12, 7))
plt.plot(df.index, df['Close'], label='Vrijednost kroz vrijeme', color='deepskyblue', linewidth=2)
plt.title(coins[1] + ' cijene')
plt.xlabel('Datum')
plt.ylabel('Vrijednost')
plt.legend()
plt.grid(True)
plt.show()

# %%
mean_value = df['log_returns'].mean()
std_dev = df['log_returns'].std()

print(f"Prosječna vrijednost: {mean_value:.5f}")
print(f"Standardna devijacija: {std_dev:.5f}")
# Out:
# Prosječna vrijednost: 0.00499
# Standardna devijacija: 0.07499

# %% [markdown]
# ### Bitcoin

# %%
df = dataframes[coins[2]]
df['log_returns'] = np.log(df['Close'] / df['Open'])

plt.figure(figsize=(12, 7))
plt.plot(df.index, df['log_returns'], label='Vrijednost kroz vrijeme', color='deepskyblue', linewidth=2)
plt.title(coins[2] + ' povrati')
plt.xlabel('Datum')
plt.ylabel('Vrijednost')
plt.legend()
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(12, 7))
plt.plot(df.index, df['Close'], label='Vrijednost kroz vrijeme', color='deepskyblue', linewidth=2)
plt.title(coins[2] + ' cijene')
plt.xlabel('Datum')
plt.ylabel('Vrijednost')
plt.legend()
plt.grid(True)
plt.show()

# %%
mean_value = df['log_returns'].mean()
std_dev = df['log_returns'].std()

print(f"Prosječna vrijednost: {mean_value:.5f}")
print(f"Standardna devijacija: {std_dev:.5f}")
# Out:
# Prosječna vrijednost: 0.00176
# Standardna devijacija: 0.04269

# %% [markdown]
# ### Cardano

# %%
df = dataframes[coins[3]]
df['log_returns'] = np.log(df['Close'] / df['Open'])

plt.figure(figsize=(12, 7))
plt.plot(df.index, df['log_returns'], label='Vrijednost kroz vrijeme', color='deepskyblue', linewidth=2)
plt.title(coins[3] + ' povrati')
plt.xlabel('Datum')
plt.ylabel('Vrijednost')
plt.legend()
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(12, 7))
plt.plot(df.index, df['Close'], label='Vrijednost kroz vrijeme', color='deepskyblue', linewidth=2)
plt.title(coins[3] + ' cijene')
plt.xlabel('Datum')
plt.ylabel('Vrijednost')
plt.legend()
plt.grid(True)
plt.show()

# %%
mean_value = df['log_returns'].mean()
std_dev = df['log_returns'].std()

print(f"Prosječna vrijednost: {mean_value:.5f}")
print(f"Standardna devijacija: {std_dev:.5f}")
# Out:
# Prosječna vrijednost: 0.00303
# Standardna devijacija: 0.07437

# %% [markdown]
# ### ChainLink

# %%
df = dataframes[coins[4]]
df['log_returns'] = np.log(df['Close'] / df['Open'])

plt.figure(figsize=(12, 7))
plt.plot(df.index, df['log_returns'], label='Vrijednost kroz vrijeme', color='deepskyblue', linewidth=2)
plt.title(coins[4] + ' povrati')
plt.xlabel('Datum')
plt.ylabel('Vrijednost')
plt.legend()
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(12, 7))
plt.plot(df.index, df['Close'], label='Vrijednost kroz vrijeme', color='deepskyblue', linewidth=2)
plt.title(coins[4] + ' cijene')
plt.xlabel('Datum')
plt.ylabel('Vrijednost')
plt.legend()
plt.grid(True)
plt.show()

# %%
mean_value = df['log_returns'].mean()
std_dev = df['log_returns'].std()

print(f"Prosječna vrijednost: {mean_value:.5f}")
print(f"Standardna devijacija: {std_dev:.5f}")
# Out:
# Prosječna vrijednost: 0.00318
# Standardna devijacija: 0.07836

# %% [markdown]
# ### Cosmos

# %%
df = dataframes[coins[5]]
df['log_returns'] = np.log(df['Close'] / df['Open'])

plt.figure(figsize=(12, 7))
plt.plot(df.index, df['log_returns'], label='Vrijednost kroz vrijeme', color='deepskyblue', linewidth=2)
plt.title(coins[5] + ' povrati')
plt.xlabel('Datum')
plt.ylabel('Vrijednost')
plt.legend()
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(12, 7))
plt.plot(df.index, df['Close'], label='Vrijednost kroz vrijeme', color='deepskyblue', linewidth=2)
plt.title(coins[5] + ' cijene')
plt.xlabel('Datum')
plt.ylabel('Vrijednost')
plt.legend()
plt.grid(True)
plt.show()

# %%
mean_value = df['log_returns'].mean()
std_dev = df['log_returns'].std()

print(f"Prosječna vrijednost: {mean_value:.5f}")
print(f"Standardna devijacija: {std_dev:.5f}")
# Out:
# Prosječna vrijednost: 0.00084
# Standardna devijacija: 0.07374

# %% [markdown]
# ### CryptocomCoin

# %%
df = dataframes[coins[6]]
df['log_returns'] = np.log(df['Close'] / df['Open'])

plt.figure(figsize=(12, 7))
plt.plot(df.index, df['log_returns'], label='Vrijednost kroz vrijeme', color='deepskyblue', linewidth=2)
plt.title(coins[6] + ' povrati')
plt.xlabel('Datum')
plt.ylabel('Vrijednost')
plt.legend()
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(12, 7))
plt.plot(df.index, df['Close'], label='Vrijednost kroz vrijeme', color='deepskyblue', linewidth=2)
plt.title(coins[6] + ' cijene')
plt.xlabel('Datum')
plt.ylabel('Vrijednost')
plt.legend()
plt.grid(True)
plt.show()

# %%
mean_value = df['log_returns'].mean()
std_dev = df['log_returns'].std()

print(f"Prosječna vrijednost: {mean_value:.5f}")
print(f"Standardna devijacija: {std_dev:.5f}")
# Out:
# Prosječna vrijednost: 0.00196
# Standardna devijacija: 0.07085

# %% [markdown]
# ### Dogecoin

# %%
df = dataframes[coins[7]]
df['log_returns'] = np.log(df['Close'] / df['Open'])

plt.figure(figsize=(12, 7))
plt.plot(df.index, df['log_returns'], label='Vrijednost kroz vrijeme', color='deepskyblue', linewidth=2)
plt.title(coins[7] + ' povrati')
plt.xlabel('Datum')
plt.ylabel('Vrijednost')
plt.legend()
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(12, 7))
plt.plot(df.index, df['Close'], label='Vrijednost kroz vrijeme', color='deepskyblue', linewidth=2)
plt.title(coins[7] + ' cijene')
plt.xlabel('Datum')
plt.ylabel('Vrijednost')
plt.legend()
plt.grid(True)
plt.show()

# %%
mean_value = df['log_returns'].mean()
std_dev = df['log_returns'].std()

print(f"Prosječna vrijednost: {mean_value:.5f}")
print(f"Standardna devijacija: {std_dev:.5f}")
# Out:
# Prosječna vrijednost: 0.00242
# Standardna devijacija: 0.08330

# %% [markdown]
# ### EOS

# %%
df = dataframes[coins[8]]
df['log_returns'] = np.log(df['Close'] / df['Open'])

plt.figure(figsize=(12, 7))
plt.plot(df.index, df['log_returns'], label='Vrijednost kroz vrijeme', color='deepskyblue', linewidth=2)
plt.title(coins[8] + ' povrati')
plt.xlabel('Datum')
plt.ylabel('Vrijednost')
plt.legend()
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(12, 7))
plt.plot(df.index, df['Close'], label='Vrijednost kroz vrijeme', color='deepskyblue', linewidth=2)
plt.title(coins[8] + ' cijene')
plt.xlabel('Datum')
plt.ylabel('Vrijednost')
plt.legend()
plt.grid(True)
plt.show()

# %%
mean_value = df['log_returns'].mean()
std_dev = df['log_returns'].std()

print(f"Prosječna vrijednost: {mean_value:.5f}")
print(f"Standardna devijacija: {std_dev:.5f}")
# Out:
# Prosječna vrijednost: 0.00080
# Standardna devijacija: 0.07828

# %% [markdown]
# ### Ethereum

# %%
df = dataframes[coins[9]]
df['log_returns'] = np.log(df['Close'] / df['Open'])

plt.figure(figsize=(12, 7))
plt.plot(df.index, df['log_returns'], label='Vrijednost kroz vrijeme', color='deepskyblue', linewidth=2)
plt.title(coins[9] + ' povrati')
plt.xlabel('Datum')
plt.ylabel('Vrijednost')
plt.legend()
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(12, 7))
plt.plot(df.index, df['Close'], label='Vrijednost kroz vrijeme', color='deepskyblue', linewidth=2)
plt.title(coins[9] + ' cijene')
plt.xlabel('Datum')
plt.ylabel('Vrijednost')
plt.legend()
plt.grid(True)
plt.show()

# %%
mean_value = df['log_returns'].mean()
std_dev = df['log_returns'].std()

print(f"Prosječna vrijednost: {mean_value:.5f}")
print(f"Standardna devijacija: {std_dev:.5f}")
# Out:
# Prosječna vrijednost: 0.00290
# Standardna devijacija: 0.06803

# %% [markdown]
# ### Iota

# %%
df = dataframes[coins[10]]
df['log_returns'] = np.log(df['Close'] / df['Open'])

plt.figure(figsize=(12, 7))
plt.plot(df.index, df['log_returns'], label='Vrijednost kroz vrijeme', color='deepskyblue', linewidth=2)
plt.title(coins[10] + ' povrati')
plt.xlabel('Datum')
plt.ylabel('Vrijednost')
plt.legend()
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(12, 7))
plt.plot(df.index, df['Close'], label='Vrijednost kroz vrijeme', color='deepskyblue', linewidth=2)
plt.title(coins[10] + ' cijene')
plt.xlabel('Datum')
plt.ylabel('Vrijednost')
plt.legend()
plt.grid(True)
plt.show()

# %%
mean_value = df['log_returns'].mean()
std_dev = df['log_returns'].std()

print(f"Prosječna vrijednost: {mean_value:.5f}")
print(f"Standardna devijacija: {std_dev:.5f}")
# Out:
# Prosječna vrijednost: 0.00014
# Standardna devijacija: 0.07332

# %% [markdown]
# ### Litecoin

# %%
df = dataframes[coins[11]]
df['log_returns'] = np.log(df['Close'] / df['Open'])

plt.figure(figsize=(12, 7))
plt.plot(df.index, df['log_returns'], label='Vrijednost kroz vrijeme', color='deepskyblue', linewidth=2)
plt.title(coins[11] + ' povrati')
plt.xlabel('Datum')
plt.ylabel('Vrijednost')
plt.legend()
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(12, 7))
plt.plot(df.index, df['Close'], label='Vrijednost kroz vrijeme', color='deepskyblue', linewidth=2)
plt.title(coins[11] + ' cijene')
plt.xlabel('Datum')
plt.ylabel('Vrijednost')
plt.legend()
plt.grid(True)
plt.show()

# %%
mean_value = df['log_returns'].mean()
std_dev = df['log_returns'].std()

print(f"Prosječna vrijednost: {mean_value:.5f}")
print(f"Standardna devijacija: {std_dev:.5f}")
# Out:
# Prosječna vrijednost: 0.00088
# Standardna devijacija: 0.06377

# %% [markdown]
# ### Monero

# %%
df = dataframes[coins[12]]
df['log_returns'] = np.log(df['Close'] / df['Open'])

plt.figure(figsize=(12, 7))
plt.plot(df.index, df['log_returns'], label='Vrijednost kroz vrijeme', color='deepskyblue', linewidth=2)
plt.title(coins[12] + ' povrati')
plt.xlabel('Datum')
plt.ylabel('Vrijednost')
plt.legend()
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(12, 7))
plt.plot(df.index, df['Close'], label='Vrijednost kroz vrijeme', color='deepskyblue', linewidth=2)
plt.title(coins[12] + ' cijene')
plt.xlabel('Datum')
plt.ylabel('Vrijednost')
plt.legend()
plt.grid(True)
plt.show()

# %%
mean_value = df['log_returns'].mean()
std_dev = df['log_returns'].std()

print(f"Prosječna vrijednost: {mean_value:.5f}")
print(f"Standardna devijacija: {std_dev:.5f}")
# Out:
# Prosječna vrijednost: 0.00180
# Standardna devijacija: 0.06797

# %% [markdown]
# ### NEM

# %%
df = dataframes[coins[13]]
df['log_returns'] = np.log(df['Close'] / df['Open'])

plt.figure(figsize=(12, 7))
plt.plot(df.index, df['log_returns'], label='Vrijednost kroz vrijeme', color='deepskyblue', linewidth=2)
plt.title(coins[13] + ' povrati')
plt.xlabel('Datum')
plt.ylabel('Vrijednost')
plt.legend()
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(12, 7))
plt.plot(df.index, df['Close'], label='Vrijednost kroz vrijeme', color='deepskyblue', linewidth=2)
plt.title(coins[13] + ' cijene')
plt.xlabel('Datum')
plt.ylabel('Vrijednost')
plt.legend()
plt.grid(True)
plt.show()

# %%
mean_value = df['log_returns'].mean()
std_dev = df['log_returns'].std()

print(f"Prosječna vrijednost: {mean_value:.5f}")
print(f"Standardna devijacija: {std_dev:.5f}")
# Out:
# Prosječna vrijednost: 0.00256
# Standardna devijacija: 0.07888

# %% [markdown]
# ### Polkadot

# %%
df = dataframes[coins[14]]
df['log_returns'] = np.log(df['Close'] / df['Open'])

plt.figure(figsize=(12, 7))
plt.plot(df.index, df['log_returns'], label='Vrijednost kroz vrijeme', color='deepskyblue', linewidth=2)
plt.title(coins[14] + ' povrati')
plt.xlabel('Datum')
plt.ylabel('Vrijednost')
plt.legend()
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(12, 7))
plt.plot(df.index, df['Close'], label='Vrijednost kroz vrijeme', color='deepskyblue', linewidth=2)
plt.title(coins[14] + ' cijene')
plt.xlabel('Datum')
plt.ylabel('Vrijednost')
plt.legend()
plt.grid(True)
plt.show()

# %%
mean_value = df['log_returns'].mean()
std_dev = df['log_returns'].std()

print(f"Prosječna vrijednost: {mean_value:.5f}")
print(f"Standardna devijacija: {std_dev:.5f}")
# Out:
# Prosječna vrijednost: 0.00505
# Standardna devijacija: 0.08353

# %% [markdown]
# ### Solana

# %%
df = dataframes[coins[15]]
df['log_returns'] = np.log(df['Close'] / df['Open'])

plt.figure(figsize=(12, 7))
plt.plot(df.index, df['log_returns'], label='Vrijednost kroz vrijeme', color='deepskyblue', linewidth=2)
plt.title(coins[15] + ' povrati')
plt.xlabel('Datum')
plt.ylabel('Vrijednost')
plt.legend()
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(12, 7))
plt.plot(df.index, df['Close'], label='Vrijednost kroz vrijeme', color='deepskyblue', linewidth=2)
plt.title(coins[15] + ' cijene')
plt.xlabel('Datum')
plt.ylabel('Vrijednost')
plt.legend()
plt.grid(True)
plt.show()

# %%
mean_value = df['log_returns'].mean()
std_dev = df['log_returns'].std()

print(f"Prosječna vrijednost: {mean_value:.5f}")
print(f"Standardna devijacija: {std_dev:.5f}")
# Out:
# Prosječna vrijednost: 0.00782
# Standardna devijacija: 0.09363

# %% [markdown]
# ### Stellar

# %%
df = dataframes[coins[16]]
df['log_returns'] = np.log(df['Close'] / df['Open'])

plt.figure(figsize=(12, 7))
plt.plot(df.index, df['log_returns'], label='Vrijednost kroz vrijeme', color='deepskyblue', linewidth=2)
plt.title(coins[16] + ' povrati')
plt.xlabel('Datum')
plt.ylabel('Vrijednost')
plt.legend()
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(12, 7))
plt.plot(df.index, df['Close'], label='Vrijednost kroz vrijeme', color='deepskyblue', linewidth=2)
plt.title(coins[16] + ' cijene')
plt.xlabel('Datum')
plt.ylabel('Vrijednost')
plt.legend()
plt.grid(True)
plt.show()

# %%
mean_value = df['log_returns'].mean()
std_dev = df['log_returns'].std()

print(f"Prosječna vrijednost: {mean_value:.5f}")
print(f"Standardna devijacija: {std_dev:.5f}")
# Out:
# Prosječna vrijednost: 0.00191
# Standardna devijacija: 0.07415

# %% [markdown]
# ### Tether

# %%
df = dataframes[coins[17]]
df['log_returns'] = np.log(df['Close'] / df['Open'])

plt.figure(figsize=(12, 7))
plt.plot(df.index, df['log_returns'], label='Vrijednost kroz vrijeme', color='deepskyblue', linewidth=2)
plt.title(coins[17] + ' povrati')
plt.xlabel('Datum')
plt.ylabel('Vrijednost')
plt.legend()
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(12, 7))
plt.plot(df.index, df['Close'], label='Vrijednost kroz vrijeme', color='deepskyblue', linewidth=2)
plt.title(coins[17] + ' cijene')
plt.xlabel('Datum')
plt.ylabel('Vrijednost')
plt.legend()
plt.grid(True)
plt.show()

# %%
mean_value = df['log_returns'].mean()
std_dev = df['log_returns'].std()

print(f"Prosječna vrijednost: {mean_value:.5f}")
print(f"Standardna devijacija: {std_dev:.5f}")
# Out:
# Prosječna vrijednost: 0.00005
# Standardna devijacija: 0.00526

# %% [markdown]
# ### Tron

# %%
df = dataframes[coins[18]]
df['log_returns'] = np.log(df['Close'] / df['Open'])

plt.figure(figsize=(12, 7))
plt.plot(df.index, df['log_returns'], label='Vrijednost kroz vrijeme', color='deepskyblue', linewidth=2)
plt.title(coins[18] + ' povrati')
plt.xlabel('Datum')
plt.ylabel('Vrijednost')
plt.legend()
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(12, 7))
plt.plot(df.index, df['Close'], label='Vrijednost kroz vrijeme', color='deepskyblue', linewidth=2)
plt.title(coins[18] + ' cijene')
plt.xlabel('Datum')
plt.ylabel('Vrijednost')
plt.legend()
plt.grid(True)
plt.show()

# %%
mean_value = df['log_returns'].mean()
std_dev = df['log_returns'].std()

print(f"Prosječna vrijednost: {mean_value:.5f}")
print(f"Standardna devijacija: {std_dev:.5f}")
# Out:
# Prosječna vrijednost: 0.00233
# Standardna devijacija: 0.08490

# %% [markdown]
# ### USDCoin

# %%
df = dataframes[coins[19]]
df['log_returns'] = np.log(df['Close'] / df['Open'])

plt.figure(figsize=(12, 7))
plt.plot(df.index, df['log_returns'], label='Vrijednost kroz vrijeme', color='deepskyblue', linewidth=2)
plt.title(coins[19] + ' povrati')
plt.xlabel('Datum')
plt.ylabel('Vrijednost')
plt.legend()
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(12, 7))
plt.plot(df.index, df['Close'], label='Vrijednost kroz vrijeme', color='deepskyblue', linewidth=2)
plt.title(coins[19] + ' cijene')
plt.xlabel('Datum')
plt.ylabel('Vrijednost')
plt.legend()
plt.grid(True)
plt.show()

# %%
mean_value = df['log_returns'].mean()
std_dev = df['log_returns'].std()

print(f"Prosječna vrijednost: {mean_value:.5f}")
print(f"Standardna devijacija: {std_dev:.5f}")
# Out:
# Prosječna vrijednost: 0.00002
# Standardna devijacija: 0.00465

# %% [markdown]
# ### Uniswap

# %%
df = dataframes[coins[20]]
df['log_returns'] = np.log(df['Close'] / df['Open'])

plt.figure(figsize=(12, 7))
plt.plot(df.index, df['log_returns'], label='Vrijednost kroz vrijeme', color='deepskyblue', linewidth=2)
plt.title(coins[20] + ' povrati')
plt.xlabel('Datum')
plt.ylabel('Vrijednost')
plt.legend()
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(12, 7))
plt.plot(df.index, df['Close'], label='Vrijednost kroz vrijeme', color='deepskyblue', linewidth=2)
plt.title(coins[20] + ' cijene')
plt.xlabel('Datum')
plt.ylabel('Vrijednost')
plt.legend()
plt.grid(True)
plt.show()

# %%
mean_value = df['log_returns'].mean()
std_dev = df['log_returns'].std()

print(f"Prosječna vrijednost: {mean_value:.5f}")
print(f"Standardna devijacija: {std_dev:.5f}")
# Out:
# Prosječna vrijednost: 0.00628
# Standardna devijacija: 0.09709

# %% [markdown]
# ### WrappedBitcoin

# %%
df = dataframes[coins[21]]
df['log_returns'] = np.log(df['Close'] / df['Open'])

plt.figure(figsize=(12, 7))
plt.plot(df.index, df['log_returns'], label='Vrijednost kroz vrijeme', color='deepskyblue', linewidth=2)
plt.title(coins[21] + ' povrati')
plt.xlabel('Datum')
plt.ylabel('Vrijednost')
plt.legend()
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(12, 7))
plt.plot(df.index, df['Close'], label='Vrijednost kroz vrijeme', color='deepskyblue', linewidth=2)
plt.title(coins[21] + ' cijene')
plt.xlabel('Datum')
plt.ylabel('Vrijednost')
plt.legend()
plt.grid(True)
plt.show()

# %%
mean_value = df['log_returns'].mean()
std_dev = df['log_returns'].std()

print(f"Prosječna vrijednost: {mean_value:.5f}")
print(f"Standardna devijacija: {std_dev:.5f}")
# Out:
# Prosječna vrijednost: 0.00256
# Standardna devijacija: 0.04324

# %% [markdown]
# ### XRP

# %%
df = dataframes[coins[22]]
df['log_returns'] = np.log(df['Close'] / df['Open'])

plt.figure(figsize=(12, 7))
plt.plot(df.index, df['log_returns'], label='Vrijednost kroz vrijeme', color='deepskyblue', linewidth=2)
plt.title(coins[22] + ' povrati')
plt.xlabel('Datum')
plt.ylabel('Vrijednost')
plt.legend()
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(12, 7))
plt.plot(df.index, df['Close'], label='Vrijednost kroz vrijeme', color='deepskyblue', linewidth=2)
plt.title(coins[22] + ' cijene')
plt.xlabel('Datum')
plt.ylabel('Vrijednost')
plt.legend()
plt.grid(True)
plt.show()

# %%
mean_value = df['log_returns'].mean()
std_dev = df['log_returns'].std()

print(f"Prosječna vrijednost: {mean_value:.5f}")
print(f"Standardna devijacija: {std_dev:.5f}")
# Out:
# Prosječna vrijednost: 0.00155
# Standardna devijacija: 0.07278
